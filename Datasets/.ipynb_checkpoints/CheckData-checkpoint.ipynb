# %% [markdown]
# # Creating data part2
#
# #### y = Tx
# #### Gaussian Noise
# #### Export

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# %%
df=pd.read_csv('data_lisse.csv', sep=',',header=None)
data = df.values

# %%
type(data)
# Out:
# numpy.ndarray

# %%
data.shape
# Out:
# (3600, 200)

# %% [markdown]
# #### y= Tx

# %%
# Physical data
l = 1
tau = 1
dep = 1
# Numerical data
nx = 200
dx = 1/nx
T_op = dx*np.tri(nx, nx, 0, dtype=int).T

# %%
T_op.shape
# Out:
# (200, 200)

# %%
Npoint, nx = data.shape

# %%
y = np.zeros((Npoint,nx))
for i in range(Npoint):
    y[i] = T_op.dot(data[i])

# %%
plt.plot(y[22])
plt.plot(y[55])
plt.plot(y[2000])

# %% [markdown]
# #### Gaussian noise

# %%
y_noise = np.zeros((Npoint,nx))
liste_histr = []
for i in range(Npoint):

# %%
len(liste_histr)
# Out:
# 3600

# %%
plt.plot(y_noise[22])
plt.plot(y_noise[55])
plt.plot(y_noise[2000])

# %% [markdown]
# ####  Export

# %%
np.savetxt('data_blurred.csv', liste_histr, delimiter=', ', fmt='%12.8f')

# %%
nx =10
np.random.randn(nx)
# Out:
# array([ 0.44589523, -0.91835893,  0.58190553, -1.4792945 ,  0.07453799,
#         1.09847485, -0.42720401,  0.93995899,  0.44338682, -0.50853706])
