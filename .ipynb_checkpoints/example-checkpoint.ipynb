# %% [markdown]
# # FBRESNET - one example

# %%
# importation
import numpy as np
from torch.autograd import Variable
import torch
import matplotlib.pyplot as plt
# %matplotlib inline
# local
from FBRN.myfunc import Physics
from FBRN.myfunc import MyMatmul
from FBRN.main import FBRestNet
from FBRN.model import MyModel
from FBRN.myfunc import Export_hyper

# %% [markdown]
# ### Initialisation
# The condition are as follows:
# $a=1$ ,
# $p=1$ ,
# the constraint is $0 <x_i <1$ .

# %%
exp1 = FBRestNet(experimentation=Physics(2000,100,1,1), nb_blocks=20, noise = 0.05,\
                 folder = './', im_set="Set1",batch_size=[100,1],\
                 lr=1e-3, nb_epochs=[20,1])

# %% [markdown]
# ### Dataset
# Here, the dataset is of size 300, which is split in 200 trainig datas and 100 validation datas.

# %%
train_set, val_set = exp1.CreateDataSet()

# %% [markdown]
# ### Trainings
# The training is done over 20 epochs, learning rate is $10^{-3}$.
# The Lipschitz constant is plot duroing training.
# Here the parameter can be saved after training in file 'Trainings', and uploaded later.

# %%
exp1.train(train_set,val_set,save_model=False)
# Out:
# epoch :  0  -----  validation :  6.080809725972358e-05
#            ----- initial error : 0.003474269705210728
# epoch :  1  -----  validation :  5.976235854287745e-05
#            ----- initial error : 0.003474269705210728
# epoch :  2  -----  validation :  5.875495337408431e-05
#            ----- initial error : 0.003474269705210728
# epoch :  3  -----  validation :  5.801816344804441e-05
#            ----- initial error : 0.003474269705210728
# epoch :  4  -----  validation :  5.7481391415807813e-05
#            ----- initial error : 0.003474269705210728
# epoch :  5  -----  validation :  5.706029746348081e-05
#            ----- initial error : 0.003474269705210728
# epoch :  6  -----  validation :  5.686685361786548e-05
#            ----- initial error : 0.003474269705210728
# epoch :  7  -----  validation :  5.693032995402587e-05
#            ----- initial error : 0.003474269705210728
# epoch :  8  -----  validation :  5.7074784501420446e-05
#            ----- initial error : 0.003474269705210728
# epoch :  9  -----  validation :  5.711070099840237e-05
#            ----- initial error : 0.003474269705210728
# epoch :  10  -----  validation :  5.7127300985457346e-05
#            ----- initial error : 0.003474269705210728
# epoch :  11  -----  validation :  5.7200427832096025e-05
#            ----- initial error : 0.003474269705210728
# epoch :  12  -----  validation :  5.724451026859848e-05
#            ----- initial error : 0.003474269705210728
# epoch :  13  -----  validation :  5.7224466934602596e-05
#            ----- initial error : 0.003474269705210728
# epoch :  14  -----  validation :  5.7229076308872074e-05
#            ----- initial error : 0.003474269705210728
# epoch :  15  -----  validation :  5.731680434881569e-05
#            ----- initial error : 0.003474269705210728
# epoch :  16  -----  validation :  5.7339616570530005e-05
#            ----- initial error : 0.003474269705210728
# epoch :  17  -----  validation :  5.7365025537420124e-05
#            ----- initial error : 0.003474269705210728
# epoch :  18  -----  validation :  5.73842706657932e-05
#            ----- initial error : 0.003474269705210728
# epoch :  19  -----  validation :  5.741141406664004e-05
#            ----- initial error : 0.003474269705210728
# -----------------------------------------------------------------
# Training is done.
# -----------------------------------------------------------------
# Final Lipschitz constant =  0.001097753250804063

# %% [markdown]
# ### Testing
# We computre the averaged error over the testing set, and compute one example, on the left the signal are projected on the eigenbasis of operator $T_a^TT_a$, on the right on the finite element basis.

# %%
average_error = exp1.test(val_set)
# Out:
# Erreur de sortie :  0.02103273358265642
# Erreur initiale :  0.8673830897327764

# %% [markdown]
# ### Test on a Gaussian function

# %%
exp1.test_gauss(noise=0.05)
# Out:
# <class 'str'>
# |x-xp|/|x| = 0.4995120531679051

# %% [markdown]
# ### Lipschitz constant
#
# Here we implement for the Gaussian signal the lipschitz constant of the neural network, depending on the input. s or if

# %% [markdown]
# $x_{in}=x_{bias}=T_a^T y^\delta$

# %%
exp1.model.Lipschitz(opt1="semi",opt2="entree11")
# Out:
# 0.049412076824233424

# %% [markdown]
# $x_{in}= 0$, and $x_{bias}= T_a^T y^\delta$

# %%
exp1.model.Lipschitz(opt1="semi",opt2="entree01")
# Out:
# 0.0010970796806517129
